# %%
### Notebook to test DNN Class|
from DomAdpQSAR.utility import gpu, seed_all

from DomAdpQSAR.QSARsettings import Settings

# %%
from DomAdpQSAR.QSARdnn import DomAdpQSARDNN

# %%
test_settings = Settings()
test_settings.trial_name = "test2"
test_Experiment = DomAdpQSARDNN(test_settings)

# %%
test_Experiment.model_setup()

# %%
test_Experiment.dataset_setup()

# %%
test_Experiment.set_rank('Tanimoto')

# %%
test_Experiment.train_dataset_loader = test_Experiment.clean_dataset_loader

# %%
device = 'cpu'
print(test_settings.summary_step_period)
# Out:
# 50

# %%
test_Experiment.train()
# Out:
# logs/test2 r6
# Step 0, 0:00:00.140963...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.4683)
# BAC:  tensor(0.5000)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.4620)
# BAC:  tensor(0.5000)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.2473)
# BAC:  tensor(0.5000)
# Step 50, 0:00:03.291551...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.7959)
# BAC:  tensor(0.7947)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7471)
# BAC:  tensor(0.7461)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8398)
# BAC:  tensor(0.7440)
# Step 100, 0:00:03.371182...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.8572)
# BAC:  tensor(0.8561)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7780)
# BAC:  tensor(0.7770)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8503)
# BAC:  tensor(0.7597)
# Step 150, 0:00:03.059121...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.8955)
# BAC:  tensor(0.8940)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7915)
# BAC:  tensor(0.7896)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8560)
# BAC:  tensor(0.7616)
# Step 200, 0:00:02.693397...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9278)
# BAC:  tensor(0.9263)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.8037)
# BAC:  tensor(0.8018)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8611)
# BAC:  tensor(0.7680)
# Step 250, 0:00:02.991885...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9497)
# BAC:  tensor(0.9485)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.8044)
# BAC:  tensor(0.8023)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8624)
# BAC:  tensor(0.7683)
# Step 300, 0:00:03.049525...ize([218, 2048]))Evaluating on Training dataset:
# Accuracy:  tensor(0.9653)
# BAC:  tensor(0.9641)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.8076)
# BAC:  tensor(0.8053)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8606)
# BAC:  tensor(0.7671)
# Step 350, 0:00:02.733458...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9764)
# BAC:  tensor(0.9757)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.8044)
# BAC:  tensor(0.8032)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8588)
# BAC:  tensor(0.7684)
# Step 400, 0:00:02.588303...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9813)
# BAC:  tensor(0.9808)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.8044)
# BAC:  tensor(0.8027)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8538)
# BAC:  tensor(0.7595)
# Step 450, 0:00:02.622075...Evaluating on Training dataset:
# Accuracy:  tensor(0.9867)
# BAC:  tensor(0.9862)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.8050)
# BAC:  tensor(0.8029)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8517)
# BAC:  tensor(0.7569)
# Step 500, 0:00:02.651870...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9884)
# BAC:  tensor(0.9882)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.8005)
# BAC:  tensor(0.7996)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8501)
# BAC:  tensor(0.7617)
# Step 550, 0:00:03.380123...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9895)
# BAC:  tensor(0.9892)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7979)
# BAC:  tensor(0.7971)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8474)
# BAC:  tensor(0.7596)
# Step 600, 0:00:02.964199...Evaluating on Training dataset:
# Accuracy:  tensor(0.9905)
# BAC:  tensor(0.9904)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7999)
# BAC:  tensor(0.7993)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8483)
# BAC:  tensor(0.7608)
# Step 650, 0:00:03.113729...ize([218, 2048]))Evaluating on Training dataset:
# Accuracy:  tensor(0.9907)
# BAC:  tensor(0.9906)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7999)
# BAC:  tensor(0.7993)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8465)
# BAC:  tensor(0.7611)
# Step 700, 0:00:03.097293...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9908)
# BAC:  tensor(0.9908)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7979)
# BAC:  tensor(0.7979)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8467)
# BAC:  tensor(0.7647)
# Step 750, 0:00:03.132097...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9912)
# BAC:  tensor(0.9910)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7992)
# BAC:  tensor(0.7992)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8467)
# BAC:  tensor(0.7662)
# Step 800, 0:00:02.914127...Evaluating on Training dataset:
# Accuracy:  tensor(0.9907)
# BAC:  tensor(0.9906)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7979)
# BAC:  tensor(0.7979)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8453)
# BAC:  tensor(0.7628)
# Step 850, 0:00:03.057330...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9908)
# BAC:  tensor(0.9908)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7921)
# BAC:  tensor(0.7923)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8423)
# BAC:  tensor(0.7655)
# Step 900, 0:00:02.750978...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9910)
# BAC:  tensor(0.9911)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7986)
# BAC:  tensor(0.7987)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8439)
# BAC:  tensor(0.7678)
# Step 950, 0:00:02.954084...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9912)
# BAC:  tensor(0.9911)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7921)
# BAC:  tensor(0.7924)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8442)
# BAC:  tensor(0.7655)
# Step 1000, 0:00:02.651399...ize([218, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9913)
# BAC:  tensor(0.9913)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7954)
# BAC:  tensor(0.7958)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8433)
# BAC:  tensor(0.7667)
# Step 1050, 0:00:02.631876...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9910)
# BAC:  tensor(0.9910)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7960)
# BAC:  tensor(0.7964)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8446)
# BAC:  tensor(0.7735)
# Step 1100, 0:00:02.547641...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9910)
# BAC:  tensor(0.9909)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7999)
# BAC:  tensor(0.7999)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8467)
# BAC:  tensor(0.7684)
# Step 1150, 0:00:02.616551...Evaluating on Training dataset:
# Accuracy:  tensor(0.9912)
# BAC:  tensor(0.9913)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7992)
# BAC:  tensor(0.8000)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8426)
# BAC:  tensor(0.7691)
# Step 1200, 0:00:03.058580...Evaluating on Training dataset:
# Accuracy:  tensor(0.9908)
# BAC:  tensor(0.9907)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7960)
# BAC:  tensor(0.7964)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8417)
# BAC:  tensor(0.7685)
# Step 1249, 0:00:02.904270...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9908)
# BAC:  tensor(0.9908)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7960)
# BAC:  tensor(0.7966)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8392)
# BAC:  tensor(0.7640)
# Completed logs/test2 r6
