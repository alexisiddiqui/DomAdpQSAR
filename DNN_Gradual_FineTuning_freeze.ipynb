# %%
### Notebook to test DNN Class|
from DomAdpQSAR.utility import gpu, seed_all

from DomAdpQSAR.QSARsettings import Settings

# %%
from DomAdpQSAR.QSARdnn import DomAdpQSARDNN

# %%
test_settings = Settings()
test_settings.trial_name = "Basic Tuning"
test_Experiment = DomAdpQSARDNN(test_settings)

# %%
# do we actually need this???
test_Experiment.dataset_setup()
test_Experiment.model_setup()

# test_Experiment.freeze_DNN_layers(0)
# for idx,param in  enumerate(test_Experiment.DNN.hidden.parameters()):
#     print(param.size())
#     print("Hidden", idx, param.requires_grad )
# for idx, param in enumerate(test_Experiment.DNN.batchnorm.parameters()):
#     print(param.size())
#     print("Batchnorm", idx, param.requires_grad )

# %%
i = 0 
for i in range(0, 3):
    test_Experiment.settings.trial_name = "Naive FT Underfit Feeeze " + str(i)
    test_Experiment.settings.load_model_path = "logs/Broad Tuning Underfit"
    # test_Experiment.set_rank('Tanimoto')
    test_Experiment.set_training_data(test_Experiment.clean_dataset_loader)

    print(f"Steps to run: {test_Experiment.settings.steps_to_run}")
    test_Experiment.settings.freeze_layers = i
    test_Experiment.train()

# %%
i = 0 
for i in range(0, 3):
    test_Experiment.settings.trial_name = "Naive FT Underfit Feeeze Ranked " + str(i)
    test_Experiment.settings.load_model_path = "logs/Broad Tuning Underfit"
    test_Experiment.set_rank('Tanimoto')
    test_Experiment.set_training_data(test_Experiment.clean_dataset_loader)
    
    print(f"Steps to run: {test_Experiment.settings.steps_to_run}")
    test_Experiment.settings.freeze_layers = i
    test_Experiment.train()

# %%
test_Experiment.settings.epochs_to_run = 200

# %%
# test_Experiment.settings.trial_name = "BT UnderfiT + Gradual Fine Tuning 25 Epochs"

# test_Experiment.settings.load_model_path = "logs/Broad Tuning Underfit"


# test_Experiment.settings.gradual_epochs = 15

# test_Experiment.gradual_fine_tune()


test_Experiment.settings.trial_name = "BT Underfit + Gradual Fine Tuning 25 Epochs Step -1"

test_Experiment.settings.load_model_path =  "logs/BT Underfit + Gradual Fine Tuning 25 Epochs/"
test_Experiment.set_training_data(test_Experiment.clean_dataset_loader)


steps_per_epoch = len(test_Experiment.train_dataset_loader)
test_Experiment.settings.steps_to_run = test_Experiment.settings.steps_to_run = steps_per_epoch * test_Experiment.settings.epochs_to_run

test_Experiment.train()
# Out:
# 7
# logs/BT Underfit + Gradual Fine Tuning 25 Epochs Step -1
# dataset rank:  Tanimoto
# Model loaded from `logs/BT Underfit + Gradual Fine Tuning 25 Epochs/model_960.pth`.
# Step 0, 0:00:00.172445...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9868)
# BAC:  tensor(0.9861)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.8005)
# BAC:  tensor(0.7957)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8403)
# BAC:  tensor(0.7016)
# Step 7, 0:00:01.496265...Evaluating on Training dataset:
# Accuracy:  tensor(0.9841)
# BAC:  tensor(0.9830)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7883)
# BAC:  tensor(0.7790)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8305)
# BAC:  tensor(0.6715)
# Step 14, 0:00:00.622451...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9828)
# BAC:  tensor(0.9816)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7773)
# BAC:  tensor(0.7657)
# Evaluating on Test dataset:
# ...

# %%
# test_Experiment.settings.trial_name = "BT UnderfiT + Gradual Fine Tuning 25 Epochs"

# test_Experiment.settings.load_model_path = "logs/Broad Tuning Underfit"


# test_Experiment.settings.gradual_epochs = 15

# test_Experiment.gradual_fine_tune()


test_Experiment.settings.trial_name = "BT Underfit + Gradual Fine Tuning 25 Epochs Step -1 Ranked"

test_Experiment.settings.load_model_path =  "logs/BT Underfit + Gradual Fine Tuning 25 Epochs/"
test_Experiment.set_rank('Tanimoto')
test_Experiment.set_training_data(test_Experiment.clean_dataset_loader)


test_Experiment.train()
# Out:
# dataset rank:  Tanimoto
# 7
# logs/BT Underfit + Gradual Fine Tuning 25 Epochs Step -1 Ranked
# dataset rank:  Tanimoto
# Model loaded from `logs/BT Underfit + Gradual Fine Tuning 25 Epochs/model_960.pth`.
# Step 0, 0:00:00.127629...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9868)
# BAC:  tensor(0.9861)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.8005)
# BAC:  tensor(0.7957)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8403)
# BAC:  tensor(0.7016)
# Step 7, 0:00:01.427620...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9841)
# BAC:  tensor(0.9830)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7883)
# BAC:  tensor(0.7790)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8305)
# BAC:  tensor(0.6715)
# Step 14, 0:00:00.906540...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9828)
# BAC:  tensor(0.9816)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7773)
# ...

# %%
# test_Experiment.settings.trial_name = "BT Underfit + Gradual Subsampling 25 Epochs"

# test_Experiment.settings.load_model_path = "logs/Broad Tuning Underfit"


# test_Experiment.settings.gradual_epochs = 15

# test_Experiment.gradual_fine_tune(rank='Tanimoto')



test_Experiment.settings.trial_name = "BT Underfit + Gradual Subsampling 25 Epochs step -1 Ranked"

test_Experiment.settings.load_model_path = "logs/BT Underfit + Gradual Subsampling 25 Epochs"
test_Experiment.set_rank('Tanimoto')

test_Experiment.set_training_data(test_Experiment.clean_dataset_loader)


test_Experiment.train()
# Out:
# dataset rank:  Tanimoto
# 7
# logs/BT Underfit + Gradual Subsampling 25 Epochs step -1 Ranked
# dataset rank:  Tanimoto
# Model loaded from `logs/BT Underfit + Gradual Subsampling 25 Epochs/model_960.pth`.
# Step 0, 0:00:00.189139...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9868)
# BAC:  tensor(0.9862)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7973)
# BAC:  tensor(0.7928)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8373)
# BAC:  tensor(0.6928)
# Step 7, 0:00:01.227856...Evaluating on Training dataset:
# Accuracy:  tensor(0.9865)
# BAC:  tensor(0.9857)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7915)
# BAC:  tensor(0.7842)
# Evaluating on Test dataset:
# Accuracy:  tensor(0.8328)
# BAC:  tensor(0.6768)
# Step 14, 0:00:00.936349...ize([1000, 2048])Evaluating on Training dataset:
# Accuracy:  tensor(0.9855)
# BAC:  tensor(0.9846)
# Evaluating on Validation dataset:
# Accuracy:  tensor(0.7915)
# BAC:  tensor(0.7825)
# ...

# %%
test_Experiment.settings.load_model_path = "Gradual Subsampling 15 Epochs"

test_Experiment.set_rank('Tanimoto')

test_Experiment.train()

# %%
test_Experiment.settings.trial_name = "Broad Tuning Ranked"
test_Experiment.set_rank('Tanimoto')
test_Experiment.set_training_data(test_Experiment.federated_dataset_loader)

# for sample in test_Experiment.federated_dataset_loader:
#     print(sample)
#     break


# for sample in test_Experiment.train_dataset_loader:
#     print(sample)
#     break

test_Experiment.train()

# %%
test_Experiment.settings.trial_name = "Broad Tuning Ranked Higher LR"
test_Experiment.set_rank('Tanimoto')
test_Experiment.set_training_data(test_Experiment.federated_dataset_loader)
test_Experiment.settings.learning_rate = 1e-3
# for sample in test_Experiment.federated_dataset_loader:
#     print(sample)
#     break


# for sample in test_Experiment.train_dataset_loader:
#     print(sample)
#     break

test_Experiment.train()

# %%
test_Experiment.settings.trial_name = "Broad Tuning Ranked Ultra LR"
test_Experiment.set_rank('Tanimoto')
test_Experiment.set_training_data(test_Experiment.federated_dataset_loader)
test_Experiment.settings.learning_rate = 1e-2
# for sample in test_Experiment.federated_dataset_loader:
#     print(sample)
#     break


# for sample in test_Experiment.train_dataset_loader:
#     print(sample)
#     break

test_Experiment.train()

# %%
test_Experiment.settings.trial_name = "Clean Tuning"
test_Experiment.set_rank(None)

# %%
test_Experiment.set_training_data(test_Experiment.clean_dataset_loader)
steps_per_epoch = len(test_Experiment.train_dataset_loader)
print(f"Steps per epoch: {steps_per_epoch}")
test_Experiment.settings.steps_to_run = steps_per_epoch * test_Experiment.settings.epochs_to_run
print(f"Steps to run: {test_Experiment.settings.steps_to_run}")

# %%
# test_Experiment.train()

# %%
test_Experiment.settings.trial_name = "Clean Tuning Ranked"
test_Experiment.set_rank('Tanimoto')
test_Experiment.set_training_data(test_Experiment.clean_dataset_loader)
test_Experiment.train()

# %%
test_Experiment.settings.trial_name = "Naive FT Overfit"
test_Experiment.set_rank(None)
test_Experiment.settings.load_model_path = "logs/Broad Tuning"
test_Experiment.settings.continue_from_previous_trial = True
test_Experiment.settings.continue_existing_experiments = False
test_Experiment.set_training_data(test_Experiment.clean_dataset_loader)
steps_per_epoch = len(test_Experiment.train_dataset_loader)
print(f"Steps per epoch: {steps_per_epoch}")
test_Experiment.settings.steps_to_run = steps_per_epoch * test_Experiment.settings.epochs_to_run
print(f"Steps to run: {test_Experiment.settings.steps_to_run}")

# %%
test_Experiment.train()

# %%
test_Experiment.settings.trial_name = "Broad Tuning Underfit"
test_Experiment.set_rank(None)
# test_Experiment.settings.load_model_path = "logs/Broad Tuning"
test_Experiment.settings.continue_from_previous_trial = True
test_Experiment.settings.continue_existing_experiments = False
test_Experiment.set_training_data(test_Experiment.federated_dataset_loader)
steps_per_epoch = len(test_Experiment.train_dataset_loader)
print(f"Steps per epoch: {steps_per_epoch}")
test_Experiment.settings.steps_to_run = 50 #steps_per_epoch * test_Experiment.settings.epochs_to_run
print(f"Steps to run: {test_Experiment.settings.steps_to_run}")

# %%
test_Experiment.train()

# %%
test_Experiment.settings.trial_name = "Naive FT Underfit"
test_Experiment.settings.load_model_path = "logs/Broad Tuning Underfit"
test_Experiment.set_training_data(test_Experiment.clean_dataset_loader)

steps_per_epoch = len(test_Experiment.train_dataset_loader)
print(f"Steps per epoch: {steps_per_epoch}")
test_Experiment.settings.steps_to_run = steps_per_epoch * test_Experiment.settings.epochs_to_run
print(f"Steps to run: {test_Experiment.settings.steps_to_run}")

# %%
test_Experiment.train()
